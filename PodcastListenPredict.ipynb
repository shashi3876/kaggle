# %% [markdown]
# <a href="https://colab.research.google.com/github/shashi3876/kaggle/blob/main/PodcastListenPredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# THis notebook contains the work done for the Kaggel playgorund competition named Predict Podcast Listening Time.

# %%
# imports

import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')

# %%
len(sample)
# Out:
# 250000

# %%
len(train)
# Out:
# 750000

# %%
test.columns
# Out:
# Index(['id', 'Podcast_Name', 'Episode_Title', 'Episode_Length_minutes',
#        'Genre', 'Host_Popularity_percentage', 'Publication_Day',
#        'Publication_Time', 'Guest_Popularity_percentage', 'Number_of_Ads',
#        'Episode_Sentiment'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['id', 'Podcast_Name', 'Episode_Title', 'Episode_Length_minutes',
#        'Genre', 'Host_Popularity_percentage', 'Publication_Day',
#        'Publication_Time', 'Guest_Popularity_percentage', 'Number_of_Ads',
#        'Episode_Sentiment', 'Listening_Time_minutes'],
#       dtype='object')

# %% [markdown]
# # EDA on the data

# %%
train['Podcast_Name'].value_counts()
# Out:
# Podcast_Name
# Tech Talks             22847
# Sports Weekly          20053
# Funny Folks            19635
# Tech Trends            19549
# Fitness First          19488
# Business Insights      19480
# Style Guide            19364
# Game Day               19272
# Melody Mix             18889
# Criminal Minds         17735
# Finance Focus          17628
# Detective Diaries      17452
# Crime Chronicles       17374
# Athlete's Arena        17327
# Fashion Forward        17280
# Tune Time              17254
# Business Briefs        17012
# Lifestyle Lounge       16661
# True Crime Stories     16373
# Sports Central         16191
# Digital Digest         16171
# Humor Hub              16144
# Mystery Matters        16002
# Comedy Corner          15927
# Joke Junction          15074
# Wellness Wave          15009
# Sport Spot             14778
# Gadget Geek            14770
# Home & Living          14686
# Laugh Line             14673
# Life Lessons           14464
# World Watch            14043
# Sound Waves            13928
# Global News            13649
# Mind & Body            13639
# Daily Digest           13391
# Money Matters          13380
# Current Affairs        13138
# Market Masters         13092
# Study Sessions         13053
# Innovators             12913
# Music Matters          12652
# Learning Lab           12291
# Educational Nuggets    12245
# Healthy Living         12198
# Brain Boost            11543
# Health Hour            11114
# News Roundup            9169
# Name: count, dtype: int64

# %%
test['Podcast_Name'].value_counts()
# Out:
# Podcast_Name
# Tech Talks             7553
# Sports Weekly          6633
# Funny Folks            6621
# Fitness First          6543
# Style Guide            6469
# Business Insights      6448
# Tech Trends            6446
# Melody Mix             6357
# Game Day               6345
# Criminal Minds         5980
# Crime Chronicles       5867
# Finance Focus          5859
# Detective Diaries      5799
# Fashion Forward        5787
# Tune Time              5733
# Lifestyle Lounge       5688
# Business Briefs        5685
# Athlete's Arena        5662
# Humor Hub              5476
# Sports Central         5424
# True Crime Stories     5417
# Mystery Matters        5268
# Comedy Corner          5258
# Digital Digest         5246
# Joke Junction          5039
# Wellness Wave          4948
# Home & Living          4933
# Laugh Line             4906
# Gadget Geek            4849
# Sport Spot             4844
# Life Lessons           4823
# Sound Waves            4689
# Global News            4625
# Mind & Body            4581
# World Watch            4556
# Current Affairs        4489
# Daily Digest           4436
# Money Matters          4429
# Study Sessions         4336
# Innovators             4295
# Market Masters         4280
# Music Matters          4272
# Learning Lab           4202
# Healthy Living         4097
# Educational Nuggets    3963
# Brain Boost            3944
# Health Hour            3762
# News Roundup           3138
# Name: count, dtype: int64

# %%
# Assuming train and test are pandas DataFrames
train_podcast_set = set(train['Podcast_Name'])
test_podcast_set = set(test['Podcast_Name'])

# Check if all Podcast_Name values in 'test' exist in 'train'
all_present = test_podcast_set.issubset(train_podcast_set)

if all_present:
    print("All Podcast_Name values from 'test' are present in 'train'.")
else:
    print("Not all Podcast_Name values from 'test' are present in 'train'.")
    # Find the missing podcast names
    missing_names = test_podcast_set - train_podcast_set
    print("Missing Podcast Names:", missing_names)
# Out:
# All Podcast_Name values from 'test' are present in 'train'.

# %%
train['Publication_Day'].value_counts()
# Out:
# Publication_Day
# Sunday       115946
# Monday       111963
# Friday       108237
# Wednesday    107886
# Thursday     104360
# Saturday     103505
# Tuesday       98103
# Name: count, dtype: int64

# %%
test['Number'] = pd.to_numeric(test['Episode_Title'].str.split().str[1])
train['Number'] = pd.to_numeric(train['Episode_Title'].str.split().str[1])

# %%
test.sample(10)
# Out:
#             id        Podcast_Name Episode_Title  Episode_Length_minutes  \
# 45096   795096         Sound Waves    Episode 35                   43.77
# 69231   819231        Learning Lab    Episode 74                  113.88
# 179050  929050           Humor Hub     Episode 5                   44.12
# 231442  981442      Sports Central    Episode 62                   39.85
# 163442  913442      Criminal Minds    Episode 17                   45.54
# 120513  870513     Mystery Matters    Episode 44                   40.71
# 150843  900843          Laugh Line    Episode 44                   64.13
# 166940  916940        News Roundup    Episode 23                  111.98
# 19494   769494       Wellness Wave    Episode 45                   76.63
# 64030   814030  True Crime Stories    Episode 15                  115.12
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 45096        Music                       20.49        Thursday
# 69231    Education                       44.74        Thursday
# 179050      Comedy                       90.33          Monday
# 231442      Sports                       27.52         Tuesday
# 163442  True Crime                       21.46          Friday
# 120513  True Crime                       31.85        Thursday
# 150843      Comedy                       28.16        Thursday
# 166940        News                       86.59          Monday
# 19494       Health                       50.43          Sunday
# 64030   True Crime                       29.54       Wednesday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 45096           Evening                        56.63            1.0
# 69231           Evening                          NaN            3.0
# 179050          Morning                        24.23            2.0
# 231442          Evening                        29.69            2.0
# 163442            Night                          NaN            3.0
# 120513        Afternoon                        97.86            1.0
# 150843            Night                        36.83            0.0
# 166940            Night                        24.19            0.0
# 19494             Night                        91.50            3.0
# 64030           Morning                        68.66            2.0
#
#        Episode_Sentiment  Number
# 45096           Positive      35
# 69231           Positive      74
# 179050          Positive       5
# 231442          Negative      62
# 163442          Positive      17
# 120513          Positive      44
# 150843          Positive      44
# 166940          Positive      23
# 19494           Negative      45
# 64030            Neutral      15

# %%
train.sample(10)
# Out:
#             id        Podcast_Name Episode_Title  Episode_Length_minutes  \
# 723668  723668     Current Affairs    Episode 70                   47.02
# 242015  242015     Business Briefs    Episode 27                   16.89
# 68197    68197       Sports Weekly    Episode 36                   84.11
# 60592    60592       Home & Living   Episode 100                   19.02
# 208987  208987       Home & Living    Episode 71                   71.45
# 363471  363471  True Crime Stories    Episode 19                   49.17
# 55903    55903    Crime Chronicles    Episode 12                     NaN
# 670556  670556      Criminal Minds    Episode 54                   79.99
# 157183  157183         Sound Waves    Episode 59                  107.88
# 419572  419572      Digital Digest    Episode 27                   53.52
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 723668        News                       48.57        Thursday
# 242015    Business                       44.91          Monday
# 68197       Sports                       42.15          Sunday
# 60592    Lifestyle                       90.63          Friday
# 208987   Lifestyle                       71.65       Wednesday
# 363471  True Crime                       74.10        Saturday
# 55903   True Crime                       56.56        Thursday
# 670556  True Crime                       49.79          Friday
# 157183       Music                       87.02          Monday
# 419572  Technology                       84.80          Monday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 723668        Afternoon                          NaN            0.0
# 242015            Night                        15.99            1.0
# 68197           Evening                        69.72            0.0
# 60592         Afternoon                        44.91            2.0
# 208987          Evening                        55.93            3.0
# 363471          Morning                        38.20            1.0
# 55903         Afternoon                        42.01            0.0
# 670556          Evening                        26.89            0.0
# 157183            Night                        55.02            0.0
# 419572          Evening                        84.59            0.0
#
#        Episode_Sentiment  Listening_Time_minutes  Number
# 723668          Positive                32.45887      70
# 242015          Negative                 7.30331      27
# 68197           Positive                83.40427      36
# 60592            Neutral                 2.13969     100
# 208987          Negative                54.03595      71
# 363471           Neutral                32.49749      19
# 55903           Negative                40.93952      12
# 670556          Negative                65.38572      54
# 157183          Positive                93.45140      59
# 419572          Negative                39.47327      27

# %%
train.isna().sum()
# Out:
# id                                  0
# Podcast_Name                        0
# Episode_Title                       0
# Episode_Length_minutes          87093
# Genre                               0
# Host_Popularity_percentage          0
# Publication_Day                     0
# Publication_Time                    0
# Guest_Popularity_percentage    146030
# Number_of_Ads                       1
# Episode_Sentiment                   0
# Listening_Time_minutes              0
# Number                              0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                                 0
# Podcast_Name                       0
# Episode_Title                      0
# Episode_Length_minutes         28736
# Genre                              0
# Host_Popularity_percentage         0
# Publication_Day                    0
# Publication_Time                   0
# Guest_Popularity_percentage    48832
# Number_of_Ads                      0
# Episode_Sentiment                  0
# Number                             0
# dtype: int64

# %% [markdown]
# Checking whether the podcast)name and episode number combinations are unique.

# %%
result_1 = train.groupby('Podcast_Name').agg({
    'Number': ['min', 'max']
})
result_2 = test.groupby('Podcast_Name').agg({
    'Number': ['min', 'max']
})

# %%
merged=result_1.merge(result_2, on='Podcast_Name', suffixes=('_train', '_test'))
merged.head()
# Out:
#                   Number_train      Number_test
#                            min  max         min  max
# Podcast_Name
# Athlete's Arena              1  100           1  100
# Brain Boost                  1  100           1  100
# Business Briefs              1  100           1  100
# Business Insights            1  100           1  100
# Comedy Corner                1  100           1  100

# %% [markdown]
# It seems like the same episode number may reappear for the same Podcast name over test and train.
#
# ## Add the percentage listened to each podcast
#
# HEre, I'm adding a new feature which is the percentage listened to each podcast. The Listening_Time_minute/Episode_Length_minutes * 100 will be used as the output of the model. First I'll try whetehr this value is always less than 100%.

# %%
train['Listened_Percentage']=train['Listening_Time_minutes']/train['Episode_Length_minutes']*100
train['Listened_Percentage'].describe()
# Out:
# count    6.629070e+05
# mean              inf
# std               NaN
# min      0.000000e+00
# 25%      5.662961e+01
# 50%      6.983871e+01
# 75%      8.223749e+01
# max               inf
# Name: Listened_Percentage, dtype: float64

# %%
# Get the top 20 highest values of 'Listened_Percentage'
top_20_percentage = train['Listened_Percentage'].nlargest(20)
print("Top 20 'Listened_Percentage' values:\n", top_20_percentage)

# Calculate the percentage of data with 'Listened_Percentage' above 100%
percentage_above_100 = (train[train['Listened_Percentage'] > 100].shape[0] / len(train)) * 100
print(f"\nPercentage of data with 'Listened_Percentage' > 100%: {percentage_above_100:.2f}%")
# Out:
# Top 20 'Listened_Percentage' values:
#  150178            inf
# 250219    9417.741935
# 453791    7889.864865
# 642283    5454.347826
# 107984    2520.331984
# 486115    2514.474494
# 553429    2514.474494
# 674029    2514.474494
# 63965      943.644963
# 3859       937.400827
# 391491     918.609339
# 235546     891.434045
# 583239     878.768745
# 480516     854.113146
# 253190     842.317154
# 696739     836.517803
# 186316     813.714012
# 119498     779.497356
# 159896     779.497356
# 197372     779.497356
# Name: Listened_Percentage, dtype: float64
#
# Percentage of data with 'Listened_Percentage' > 100%: 0.34%

# %% [markdown]
# It seems that around 34% of the podcasts have a Listened_percentage greater than 100%. We'll drop these values from the training set. Then, we'll use the average Listened_percentage as the baseline for predictions based on the podcast name.
#
# If the average Listened_percentage is null due to the unavailability of the episode length, we'll use the mean of the Listening_time_minutes for that podcast name as the prediction instead.
#
# Since we're using a mean-based baseline, I'm not going to split the training set into training and validation sets for now.

# %%
# Drop rows where Listened_percentage > 100%
train_cleaned = train[train['Listened_Percentage'] <= 100].copy()

# Group by Podcast_Name and compute:
# - average Listened_percentage
# - average Listening_time_minutes
grouped_stats = train_cleaned.groupby('Podcast_Name').agg({
    'Listened_Percentage': 'mean',
    'Listening_Time_minutes': 'mean'
}).reset_index()

# Optional: Rename columns for clarity
grouped_stats.rename(columns={
    'Listened_Percentage': 'Avg_Listened_Percentage',
    'Listening_Time_minutes': 'Avg_Listening_Time_minutes'
}, inplace=True)

# Preview
print(grouped_stats.head())
len(grouped_stats)
# Out:
#         Podcast_Name  Avg_Listened_Percentage  Avg_Listening_Time_minutes
# 0    Athlete's Arena                68.624694                   46.832812
# 1        Brain Boost                67.691371                   44.653527
# 2    Business Briefs                68.350878                   47.241432
# 3  Business Insights                67.257004                   44.161217
# 4      Comedy Corner                67.632612                   44.185392
# 48

# %%
len(test.Podcast_Name.unique())
# Out:
# 48

# %% [markdown]
# Now let's perform a lookup on the episode name to retrieve the Listening_Time_minutes column, and then generate the output results.

# %%
test_merged = test.merge(grouped_stats, on='Podcast_Name', how='left')

def compute_listening_time(row):
    if pd.notnull(row['Episode_Length_minutes']):
        return row['Episode_Length_minutes'] * row['Avg_Listened_Percentage'] / 100
    else:
        return row['Avg_Listening_Time_minutes']

test_merged['Listening_Time_minutes'] = test_merged.apply(compute_listening_time, axis=1)

# Preview
print(test_merged[['Podcast_Name', 'Episode_Length_minutes', 'Avg_Listened_Percentage',
                   'Avg_Listening_Time_minutes', 'Listening_Time_minutes']].head())
# Out:
#           Podcast_Name  Episode_Length_minutes  Avg_Listened_Percentage  \
# 0  Educational Nuggets                   78.96                67.396264
# 1          Sound Waves                   27.87                67.380592
# 2        Joke Junction                   69.10                66.939189
# 3        Comedy Corner                  115.39                67.632612
# 4         Life Lessons                   72.32                67.568575
#
#    Avg_Listening_Time_minutes  Listening_Time_minutes
# 0                   45.824576               53.216090
# 1                   44.952358               18.778971
# 2                   43.082075               46.254979
# 3                   44.185392               78.041271
# 4                   45.403412               48.865594

# %%
test_merged[['id','Listening_Time_minutes']].round(3).to_csv('submission.csv',index=False)

# %%
train.columns
# Out:
# Index(['id', 'Podcast_Name', 'Episode_Title', 'Episode_Length_minutes',
#        'Genre', 'Host_Popularity_percentage', 'Publication_Day',
#        'Publication_Time', 'Guest_Popularity_percentage', 'Number_of_Ads',
#        'Episode_Sentiment', 'Listening_Time_minutes', 'Number',
#        'Listened_Percentage'],
#       dtype='object')

# %% [markdown]
# This resulted in a score of 13.97 which is an improvement form the previous value of 27.16 (Which was the score of the sample submission).
#
# # Use of Catboost
#
# Here, I will be using Catboost directly on the training data and obtain results.

# %%
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split

# %%
# Define columns to exclude from features
exclude_cols = ['id', 'Listened_Percentage', 'Number', 'Listening_Time_minutes']
target_col = 'Listening_Time_minutes'

# Split features and target from train
X_train = train.drop(columns=exclude_cols)
y_train = train[target_col]

# Prepare test set (same feature columns)
X_test = test.drop(columns=['id', 'Number'])

# Identify categorical features (assumes object types are categorical)
categorical_features = X_train.select_dtypes(include=['object']).columns.tolist()

# Optional: split validation set from train (for early stopping)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define Pools
train_pool = Pool(X_tr, y_tr, cat_features=categorical_features)
val_pool = Pool(X_val, y_val, cat_features=categorical_features)
test_pool = Pool(X_test, cat_features=categorical_features)

# Train the model
model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.05,
    depth=6,
    eval_metric='RMSE',
    random_seed=42,
    early_stopping_rounds=50,
    verbose=100
)

model.fit(train_pool, eval_set=val_pool)

# Predict on test set
test_preds = model.predict(test_pool)

# Add predictions to test dataframe
test['Listening_Time_minutes'] = test_preds

# Optional: preview results
print(test[['Podcast_Name', 'Episode_Title', 'Listening_Time_minutes']].head())
# Out:
# 0:	learn: 26.1651826	test: 26.1495494	best: 26.1495494 (0)	total: 1.52s	remaining: 25m 21s
# 100:	learn: 13.2068661	test: 13.1620520	best: 13.1620520 (100)	total: 1m 29s	remaining: 13m 15s
# 200:	learn: 13.1432449	test: 13.1064601	best: 13.1064601 (200)	total: 2m 57s	remaining: 11m 47s
# 300:	learn: 13.1172287	test: 13.0874125	best: 13.0874125 (300)	total: 4m 18s	remaining: 10m
# 400:	learn: 13.0941681	test: 13.0695606	best: 13.0695606 (400)	total: 5m 37s	remaining: 8m 24s
# 500:	learn: 13.0758342	test: 13.0578648	best: 13.0578648 (500)	total: 6m 55s	remaining: 6m 54s
# 600:	learn: 13.0610588	test: 13.0492839	best: 13.0492839 (600)	total: 8m 19s	remaining: 5m 31s
# 700:	learn: 13.0457711	test: 13.0404601	best: 13.0404601 (700)	total: 9m 40s	remaining: 4m 7s
# 800:	learn: 13.0338194	test: 13.0342027	best: 13.0342027 (800)	total: 10m 55s	remaining: 2m 42s
# 900:	learn: 13.0224937	test: 13.0282390	best: 13.0282287 (899)	total: 12m 13s	remaining: 1m 20s
# 999:	learn: 13.0120509	test: 13.0238699	best: 13.0238679 (998)	total: 13m 31s	remaining: 0us
#
# bestTest = 13.02386788
# bestIteration = 998
#
# Shrink model to first 999 iterations.
#           Podcast_Name Episode_Title  Listening_Time_minutes
# 0  Educational Nuggets    Episode 73               55.703742
# 1          Sound Waves    Episode 23               17.630388
# 2        Joke Junction    Episode 11               50.338473
# 3        Comedy Corner    Episode 73               78.967146
# 4         Life Lessons    Episode 50               49.120850

# %%
test[['id','Listening_Time_minutes']].round(3).to_csv('submission_catboost.csv',index=False)

# %% [markdown]
# The above results give a score of 13.134 score on the submission.
#
# # Investigate more complex methods
